# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (1.26.0)

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (1.11.3)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from scipy) (1.26.0)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.23.2 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in e:\anna university books & notes\seventh semester\fyp\phase1\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('room_areas.csv')

# %%
data.head(20)
# Out:
#     Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0          0                 40.282471                 15.721436
# 1          1                 51.831299                 20.507080
# 2          2                 38.448303                 14.871094
# 3          3                 28.768250                 11.093994
# 4          4                 32.382202                 12.814453
# 5          5                 44.578674                 13.249512
# 6          6                 24.150696                 11.568604
# 7          7                 33.385803                 12.740295
# 8          8                 31.373657                 14.337158
# 9          9                 34.631653                 15.123230
# 10        10                 38.225830                 30.394775
# 11        11                 37.251892                 18.218079
# 12        12                 34.409180                 13.867493
# 13        13                 29.910278                 19.300781
# 14        14                 32.154785                 11.148376
# 15        15                 28.407349                 15.335815
# 16        16                 27.280151                 17.575378
# 17        17                 25.777222                 15.662109
# 18        18                 23.493164                 12.666138
# 19        19                 31.586243                 12.666138
#
#     Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                   4.597778                  4.983398
# 1                   5.018005                  2.185181
# 2                   8.429260                  5.072388
# 3                   3.599121                  2.442261
# 4                   5.472839                  3.737549
# 5                   9.175781                  3.371704
# 6                   4.983398                  4.004517
# 7                   6.644531                  2.966309
# 8                   7.840942                  6.941162
# 9                   7.203186                  8.236450
# 10                  5.087219                  4.844971
# 11                  4.152832                  2.906982
# 12                  4.108337                  4.449463
# 13                  4.256653                  4.785645
# 14                  5.141602                  6.684082
# 15                  5.912842                  2.729004
# 16                  6.451721                  5.210815
# 17                  9.447693                  5.205872
# 18                 11.148376                  6.080933
# 19                 10.144775                  4.291260
#
#     Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                   0.000000                  0.000000
# 1                   0.000000                 11.158264
# 2                   0.000000                  0.000000
# 3                   0.000000                  7.573975
# 4                   0.000000                  0.000000
# 5                   0.000000                 12.137146
# 6                   0.000000                  0.000000
# 7                   0.000000                  0.000000
# 8                   0.000000                  0.000000
# 9                   0.000000                  0.000000
# 10                  0.000000                  0.000000
# 11                  0.000000                  0.000000
# 12                  0.000000                  0.000000
# 13                  0.000000                  0.000000
# 14                 15.751099                  0.000000
# 15                  0.000000                  0.000000
# 16                  0.000000                  0.000000
# 17                  4.241821                  0.000000
# 18                  0.000000                  0.000000
# 19                  0.000000                  0.000000
#
#     Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                   0.000000                 10.480957
# 1                   0.000000                 17.491333
# 2                   0.000000                 12.280518
# 3                   0.000000                  8.048584
# 4                   0.000000                 13.081421
# 5                   9.492188                  0.000000
# 6                   4.884521                  9.966797
# 7                   0.000000                 16.097168
# 8                   0.000000                 11.761414
# 9                   0.000000                 12.280518
# 10                  0.000000                 11.870178
# 11                  0.000000                  9.492188
# 12                  0.000000                  9.254883
# 13                  6.051270                 12.967712
# 14                 11.212646                 11.271973
# 15                  0.000000                 21.451355
# 16                  0.000000                 16.334473
# 17                  0.000000                 15.988403
# 18                  0.000000                 14.475586
# 19                  0.000000                 11.835571
#
#     Room 8 Area (sq. meters)  Room 9 Area (sq. meters)
# 0                   0.000000                  6.199585
# 1                   0.000000                  2.689453
# 2                  12.997375                  4.805420
# 3                   0.000000                  4.805420
# 4                   0.000000                  4.118225
# 5                   0.000000                  0.000000
# 6                   0.000000                  1.868774
# 7                   0.000000                  6.362732
# 8                   0.000000                  3.697998
# 9                   0.000000                  1.631470
# 10                  0.000000                  0.000000
# 11                  0.000000                  1.458435
# 12                  0.000000                  4.034180
# 13                  5.003174                  3.381592
# 14                  0.000000                  0.000000
# 15                  0.000000                  6.555542
# 16                  0.000000                  0.000000
# 17                  0.000000                  7.069702
# 18                  0.000000                  4.271484
# 19                  0.000000                  6.555542

# %%
data.columns
# Out:
# Index(['Image ID', 'Room 0 Area (sq. meters)', 'Room 1 Area (sq. meters)',
#        'Room 2 Area (sq. meters)', 'Room 3 Area (sq. meters)',
#        'Room 4 Area (sq. meters)', 'Room 5 Area (sq. meters)',
#        'Room 6 Area (sq. meters)', 'Room 7 Area (sq. meters)',
#        'Room 8 Area (sq. meters)', 'Room 9 Area (sq. meters)'],
#       dtype='object')

# %%
data.shape
# Out:
# (80788, 11)

# %%
for i in data.columns:
    print(i,"Minimum Value: ",min(data[i]),"Maximum Value: ",max(data[i]))
# Out:
# Image ID Minimum Value:  0 Maximum Value:  80787
# Room 0 Area (sq. meters) Minimum Value:  16.13671875 Maximum Value:  61.82775879
# Room 1 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  56.19177246
# Room 2 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  29.50982666
# Room 3 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  27.8536377
# Room 4 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  35.02716064
# Room 5 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  32.94580078
# Room 6 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  39.1305542
# Room 7 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  54.54547119
# Room 8 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  30.43927002
# Room 9 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  46.48699951

# %% [markdown]
# There is always a room of type Room 0 in our dataset

# %%
import utils
print(utils.ROOM_CLASS)
# Out:
# {0: 'Living room', 1: 'Master room', 2: 'Kitchen', 3: 'Bathroom', 4: 'Dining room', 5: 'Child room', 6: 'Study room', 7: 'Second room', 8: 'Guest room', 9: 'Balcony', 10: 'Entrance', 11: 'Storage', 12: 'Wall-in', 13: 'External area', 14: 'Exterior wall', 15: 'Front door', 16: 'Interior wall', 17: 'Interior door'}

# %% [markdown]
# Room 0 means Living Room. So all floor plans will have a living room

# %%
room0 = data['Room 0 Area (sq. meters)']
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
room0.plot.hist(bins=60)
plt.title("Room 0 distribution")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, expon, lognorm, gamma, beta, weibull_min
from scipy.optimize import curve_fit

# Sample data (replace with your actual data)
data1 = room0

# Define the distribution functions and their names
fit_functions = [norm, expon, lognorm, gamma, beta, weibull_min]
dist_names = ['Normal', 'Exponential', 'Lognormal', 'Gamma', 'Beta', 'Weibull']

# Create subplots
fig, axes = plt.subplots(len(fit_functions), 1, figsize=(8, 12))

for i, (dist_func, dist_name) in enumerate(zip(fit_functions, dist_names)):
    # Fit the distribution to the data
    params = dist_func.fit(data1)
    fitted_distribution = dist_func(*params)

    # Generate x values for the fitted distribution
    x = np.linspace(min(data1), max(data1), 1000)

    # Plot the histogram of the data
    axes[i].hist(data1, bins=30, density=True, alpha=0.5, label='Data', color='blue')

    # Plot the fitted distribution curve
    axes[i].plot(x, fitted_distribution.pdf(x), label=dist_name, color='red')

    axes[i].set_title(f'{dist_name} Fit')
    axes[i].legend()

plt.tight_layout()
plt.show()
# Out:
# e:\Anna University BOOKS & NOTES\SEVENTH SEMESTER\FYP\Phase1\.venv\Lib\site-packages\scipy\stats\_continuous_distns.py:719: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)

# %%
## Fitting the graph for room 0
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, expon, lognorm, gamma, beta, weibull_min
from scipy.optimize import curve_fit

# Sample data (replace with your actual data)
data1 = room0

# Define the distribution functions and their names
fit_functions = [norm, expon, lognorm, beta, weibull_min]
dist_names = ['Normal', 'Exponential', 'Lognormal', 'Beta', 'Weibull']

# Create subplots
fig, axes = plt.subplots(len(fit_functions), 1, figsize=(8, 12))

# Define a custom gamma distribution function
def custom_gamma(x, k, theta):
    return gamma.pdf(x, k, scale=theta)

for i, (dist_func, dist_name) in enumerate(zip(fit_functions, dist_names)):
    # Fit the distribution to the data
    if dist_func == gamma:
        params, _ = curve_fit(custom_gamma, data1, p0=(1, 1))  # Specify initial guesses for k and theta
    else:
        params = dist_func.fit(data1)
    fitted_distribution = dist_func(*params)

    # Generate x values for the fitted distribution
    x = np.linspace(min(data1), max(data1), 1000)

    # Plot the histogram of the data
    axes[i].hist(data1, bins=30, density=True, alpha=0.5, label='Data', color='blue')

    # Plot the fitted distribution curve
    if dist_func == gamma:
        axes[i].plot(x, custom_gamma(x, *params), label=dist_name, color='red')
    else:
        axes[i].plot(x, fitted_distribution.pdf(x), label=dist_name, color='red')

    axes[i].set_title(f'{dist_name} Fit')
    axes[i].legend()

    # Generate and display the equation for the distribution
    if dist_func == norm:  # Normal Distribution
        mu, sigma = params
        equation = f'f(x) = (1/({sigma} * sqrt(2*pi))) * exp(-((x - {mu})^2) / (2*{sigma}^2))'
    
    elif dist_func == expon:  # Exponential Distribution
        lambda_ = params[0]
        equation = f'f(x) = {lambda_} * exp(-{lambda_} * x)'
    
    elif dist_func == lognorm:  # Log-Normal Distribution
        mu, sigma = params[0], params[1]
        equation = f'f(x) = (1/(x * {sigma} * sqrt(2*pi))) * exp(-((ln(x) - {mu})^2) / (2*{sigma}^2))'
    
    elif dist_func == gamma:  # Gamma Distribution
        k, theta = params
        equation = f'f(x) = ({k} * x^({k-1}) * exp(-x/{theta})) / ({theta}^{k} * gamma({k}))'
    
    elif dist_func == beta:  # Beta Distribution
        alpha, beta_ = params[0], params[1]
        equation = f'f(x) = (x^({alpha-1}) * (1-x)^({beta_-1})) / (B({alpha}, {beta_}))'
    
    elif dist_func == weibull_min:  # Weibull Distribution
        k, lambda_ = params[0], params[1]
        equation = f'f(x) = ({k}/{lambda_}) * (x/{lambda_})^({k-1}) * exp(-(x/{lambda_})^{k})'
    
    print(f'{dist_name} Equation: {equation}')

plt.tight_layout()
plt.show()
# Out:
# Normal Equation: f(x) = (1/(6.278314610231974 * sqrt(2*pi))) * exp(-((x - 32.34475813862381)^2) / (2*6.278314610231974^2))
# Exponential Equation: f(x) = 16.13671875 * exp(-16.13671875 * x)
# Lognormal Equation: f(x) = (1/(x * 1.9308271941822648 * sqrt(2*pi))) * exp(-((ln(x) - 0.20392231977062308)^2) / (2*1.9308271941822648^2))
# Beta Equation: f(x) = (x^(11.067968255758695) * (1-x)^(1554261.2689743848)) / (B(12.067968255758695, 1554262.2689743848))
# Weibull Equation: f(x) = (2.734566132769353/16.131088040804954) * (x/16.131088040804954)^(1.734566132769353) * exp(-(x/16.131088040804954)^2.734566132769353)

# %%
room1=data['Room 1 Area (sq. meters)']
qx = sns.jointplot(x=room0, y=room1, kind="reg", 
                   height=8, joint_kws={'line_kws':{'color':'red'}})
plt.show()

# %%
data['Total Area']=data['Room 0 Area (sq. meters)']+data['Room 1 Area (sq. meters)']+data['Room 2 Area (sq. meters)']+data['Room 3 Area (sq. meters)']+data['Room 4 Area (sq. meters)']+data['Room 5 Area (sq. meters)']+data['Room 6 Area (sq. meters)']+data['Room 7 Area (sq. meters)']+data['Room 8 Area (sq. meters)']+data['Room 9 Area (sq. meters)']

# %%
data.head(5)
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  Room 9 Area (sq. meters)  Total Area
# 0                  0.000000                  6.199585   82.265625
# 1                  0.000000                  2.689453  110.880615
# 2                 12.997375                  4.805420   96.904358
# 3                  0.000000                  4.805420   66.331604
# 4                  0.000000                  4.118225   71.606689

# %%
data.describe()
# Out:
#            Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# count  80788.000000              80788.000000              80788.000000
# mean   40393.500000                 32.344758                 13.974508
# std    23321.631111                  6.278353                  3.622044
# min        0.000000                 16.136719                  0.000000
# 25%    20196.750000                 27.972290                 12.096359
# 50%    40393.500000                 31.576355                 13.605469
# 75%    60590.250000                 36.001099                 15.498962
# max    80787.000000                 61.827759                 56.191772
#
#        Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# count              80788.000000              80788.000000
# mean                   5.555005                  4.875428
# std                    2.119295                  1.994954
# min                    0.000000                  0.000000
# 25%                    4.498901                  3.480469
# 50%                    5.364075                  4.350586
# 75%                    6.506104                  5.813965
# max                   29.509827                 27.853638
#
#        Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# count              80788.000000              80788.000000
# mean                   0.145002                  0.453750
# std                    1.230286                  2.106010
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.000000                  0.000000
# max                   35.027161                 32.945801
#
#        Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# count              80788.000000              80788.000000
# mean                   1.536096                 13.229438
# std                    3.380667                  6.049027
# min                    0.000000                  0.000000
# 25%                    0.000000                  9.610840
# 50%                    0.000000                 11.825684
# 75%                    0.000000                 16.853577
# max                   39.130554                 54.545471
#
#        Room 8 Area (sq. meters)  Room 9 Area (sq. meters)    Total Area
# count              80788.000000              80788.000000  80788.000000
# mean                   0.102985                  4.681624     76.898594
# std                    1.071360                  3.398408     11.508716
# min                    0.000000                  0.000000     48.350830
# 25%                    0.000000                  2.803162     67.537903
# 50%                    0.000000                  4.449463     75.005585
# 75%                    0.000000                  6.308350     84.198669
# max                   30.439270                 46.487000    112.744446

# %%
total_area = data['Total Area']
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
total_area.plot.hist(bins=20)
plt.title("Total Carpet Area Distribution")
plt.show()

# %%
rooms_list=['Room 0 Area (sq. meters)', 'Room 1 Area (sq. meters)',
       'Room 2 Area (sq. meters)', 'Room 3 Area (sq. meters)',
       'Room 4 Area (sq. meters)', 'Room 5 Area (sq. meters)',
       'Room 6 Area (sq. meters)', 'Room 7 Area (sq. meters)',
       'Room 8 Area (sq. meters)', 'Room 9 Area (sq. meters)']

# %%
fig, axes = plt.subplots(5, 2, figsize=(12, 18))
axes = axes.ravel()  # Flatten the 2D array for easy iteration

for i, room_name in enumerate(rooms_list):
    var = data[room_name]
    axes[i].hist(var, bins=20)
    axes[i].set_title("Area of " + room_name)

# Remove any extra empty subplots (if you have fewer than 10 rooms)
for j in range(len(rooms_list), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate the correlation matrix
correlation_matrix = data.corr()



plt.figure(figsize=(8, 6))
plt.title('Correlation Heatmap')
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(data.columns)), data.columns, rotation=45)
plt.yticks(range(len(data.columns)), data.columns)
plt.show()

# %%
data.columns
# Out:
# Index(['Image ID', 'Room 0 Area (sq. meters)', 'Room 1 Area (sq. meters)',
#        'Room 2 Area (sq. meters)', 'Room 3 Area (sq. meters)',
#        'Room 4 Area (sq. meters)', 'Room 5 Area (sq. meters)',
#        'Room 6 Area (sq. meters)', 'Room 7 Area (sq. meters)',
#        'Room 8 Area (sq. meters)', 'Room 9 Area (sq. meters)', 'Total Area'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Create subplots for house size and room size distributions
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot the distribution of house sizes (Histogram)
axes[0].hist(data['Total Area'], bins=10, color='skyblue', edgecolor='black')
axes[0].set_title('House Size Distribution')
axes[0].set_xlabel('House Size')
axes[0].set_ylabel('Frequency')

# Plot the distribution of room sizes (Kernel Density Plot)
import seaborn as sns
sns.kdeplot(data['Total Area'], ax=axes[1], color='red', fill=True)
axes[1].set_title('Room Size Distribution')
axes[1].set_xlabel('Room Size')
axes[1].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
room_class_utils = {
    0: "Living room",
    1: "Master room",
    2: "Kitchen",
    3: "Bathroom",
    4: "Dining room",
    5: "Child room",
    6: "Study room",
    7: "Second room",
    8: "Guest room",
    9: "Balcony",
    10: "Entrance",
    11: "Storage",
    12: "Wall-in",
    13: "External area",
    14: "Exterior wall",
    15: "Front door",
    16: "Interior wall",
    17: "Interior door",
}

# %%
for i in rooms_list:
    count_non_zero = (data[i] != 0).sum()
    print("Non Zero in",i,"",room_class_utils[int(i[5])],"is",count_non_zero)
# Out:
# Non Zero in Room 0 Area (sq. meters)  Living room is 80788
# Non Zero in Room 1 Area (sq. meters)  Master room is 79536
# Non Zero in Room 2 Area (sq. meters)  Kitchen is 77628
# Non Zero in Room 3 Area (sq. meters)  Bathroom is 80708
# Non Zero in Room 4 Area (sq. meters)  Dining room is 1311
# Non Zero in Room 5 Area (sq. meters)  Child room is 3874
# Non Zero in Room 6 Area (sq. meters)  Study room is 14960
# Non Zero in Room 7 Area (sq. meters)  Second room is 76893
# Non Zero in Room 8 Area (sq. meters)  Guest room is 826
# Non Zero in Room 9 Area (sq. meters)  Balcony is 67635

# %% [markdown]
# remove invalid images
#
# kitchen bathroom living room
#
# size check

# %% [markdown]
# Eliminating invalid floorplans from our initial dataset

# %%
min_size=dict()
min_size[0]=11.5
min_size[1]=11
min_size[2]=5
min_size[3]=1.8
min_size[4]=7.5
min_size[5]=9
min_size[6]=9
min_size[7]=7.5
min_size[8]=12
min_size[9]=1.5

tolerance=0.15

min_width=dict()
min_width[0]=3
min_width[1]=3
min_width[2]=1.8
min_width[3]=1.2
min_width[4]=2.5
min_width[5]=3
min_width[6]=3
min_width[7]=2.5
min_width[8]=3
min_width[9]=0.7

# %%
df=data.copy(deep=True)
df.head()
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  Room 9 Area (sq. meters)  Total Area
# 0                  0.000000                  6.199585   82.265625
# 1                  0.000000                  2.689453  110.880615
# 2                 12.997375                  4.805420   96.904358
# 3                  0.000000                  4.805420   66.331604
# 4                  0.000000                  4.118225   71.606689

# %%
df['area_valid']='x'

# %%
df.head()
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  Room 9 Area (sq. meters)  Total Area area_valid
# 0                  0.000000                  6.199585   82.265625          x
# 1                  0.000000                  2.689453  110.880615          x
# 2                 12.997375                  4.805420   96.904358          x
# 3                  0.000000                  4.805420   66.331604          x
# 4                  0.000000                  4.118225   71.606689          x

# %%
data.head()
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  Room 9 Area (sq. meters)  Total Area
# 0                  0.000000                  6.199585   82.265625
# 1                  0.000000                  2.689453  110.880615
# 2                 12.997375                  4.805420   96.904358
# 3                  0.000000                  4.805420   66.331604
# 4                  0.000000                  4.118225   71.606689

# %%
area_condition = (df['Room 0 Area (sq. meters)']/(1+tolerance) > min_size[0]) & (df['Room 1 Area (sq. meters)']/(1+tolerance) > min_size[1]) & (df['Room 2 Area (sq. meters)']/(1+tolerance) > min_size[2]) & (df['Room 3 Area (sq. meters)']/(1+tolerance) > min_size[3]) & (df['Room 4 Area (sq. meters)']/(1+tolerance) > min_size[4]) & (df['Room 5 Area (sq. meters)']/(1+tolerance) > min_size[5]) & (df['Room 6 Area (sq. meters)']/(1+tolerance) > min_size[6]) & (df['Room 7 Area (sq. meters)']/(1+tolerance) > min_size[7]) & (df['Room 8 Area (sq. meters)']/(1+tolerance) > min_size[8]) & (df['Room 8 Area (sq. meters)']/(1+tolerance) > min_size[8])

# %%
df['area_valid'] = area_condition

# %%
df.head()
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  Room 9 Area (sq. meters)  Total Area  area_valid
# 0                  0.000000                  6.199585   82.265625       False
# 1                  0.000000                  2.689453  110.880615       False
# 2                 12.997375                  4.805420   96.904358       False
# 3                  0.000000                  4.805420   66.331604       False
# 4                  0.000000                  4.118225   71.606689       False

# %%
room0_min_size=(df['Room 0 Area (sq. meters)']/(1) > min_size[0])
df['room0_valid']=room0_min_size
true_count = (df['room0_valid'] == True).sum()
print(true_count)
# Out:
# 80788

# %%
tolerance=0.2

# %%
room1_min_size=((df['Room 1 Area (sq. meters)']/(1+tolerance) > min_size[1]) | (df['Room 1 Area (sq. meters)']==0))
df['room1_valid']=room1_min_size
true_count = (df['room1_valid'] == True).sum()
print(true_count)
# Out:
# 47244

# %%
room2_min_size=((df['Room 2 Area (sq. meters)']/(1+tolerance) > min_size[2]) | (df['Room 2 Area (sq. meters)']==0))
df['room2_valid']=room2_min_size
true_count = (df['room2_valid'] == True).sum()
print(true_count)
# Out:
# 31119

# %%
room3_min_size=((df['Room 3 Area (sq. meters)']/(1+tolerance) > min_size[3]) | (df['Room 3 Area (sq. meters)']==0))
df['room3_valid']=room3_min_size
true_count = (df['room3_valid'] == True).sum()
print(true_count)
# Out:
# 79480

# %%
room4_min_size=((df['Room 4 Area (sq. meters)']/(1+tolerance) > min_size[4]) | (df['Room 4 Area (sq. meters)']==0))
df['room4_valid']=room4_min_size
true_count = (df['room4_valid'] == True).sum()
print(true_count)
# Out:
# 79996

# %%
room5_min_size=((df['Room 5 Area (sq. meters)']/(1+tolerance) > min_size[5]) | (df['Room 5 Area (sq. meters)']==0))
df['room5_valid']=room5_min_size
true_count = (df['room5_valid'] == True).sum()
print(true_count)
# Out:
# 77881

# %%
room6_min_size=((df['Room 6 Area (sq. meters)']/(1+tolerance) > min_size[6]) | (df['Room 6 Area (sq. meters)']==0))
df['room6_valid']=room6_min_size
true_count = (df['room6_valid'] == True).sum()
print(true_count)
# Out:
# 67727

# %%
room7_min_size=((df['Room 7 Area (sq. meters)']/(1+tolerance) > min_size[7]) | (df['Room 7 Area (sq. meters)']==0))
df['room7_valid']=room7_min_size
true_count = (df['room7_valid'] == True).sum()
print(true_count)
# Out:
# 70125

# %%
room8_min_size=((df['Room 8 Area (sq. meters)']/(1+tolerance) > min_size[8]) | (df['Room 8 Area (sq. meters)']==0))
df['room8_valid']=room8_min_size
true_count = (df['room8_valid'] == True).sum()
print(true_count)
# Out:
# 80027

# %%
room9_min_size=((df['Room 9 Area (sq. meters)']/(1+tolerance) > min_size[9]) | (df['Room 9 Area (sq. meters)']==0))
df['room9_valid']=room9_min_size
true_count = (df['room9_valid'] == True).sum()
print(true_count)
# Out:
# 78889

# %%
df.head()
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  ...  room0_valid  room1_valid  room2_valid  \
# 0                  0.000000  ...         True         True        False
# 1                  0.000000  ...         True         True        False
# 2                 12.997375  ...         True         True         True
# 3                  0.000000  ...         True        False        False
# 4                  0.000000  ...         True        False        False
#
#    room3_valid  room4_valid  room5_valid  room6_valid  room7_valid  \
# 0         True         True         True         True         True
# 1         True         True         True         True         True
# 2         True         True         True         True         True
# 3         True         True        False         True        False
# 4         True         True         True         True         True
#
#    room8_valid  room9_valid
# 0         True         True
# 1         True         True
# 2        False         True
# 3         True         True
# 4         True         True
#
# [5 rows x 23 columns]

# %%
df['area_valid']=df['room0_valid'] & df['room1_valid'] & df['room2_valid'] & df['room3_valid'] & df['room4_valid'] & df['room5_valid'] & df['room6_valid'] & df['room7_valid'] & df['room8_valid'] & df['room9_valid']

# %%
area_valid_count = (df['area_valid'] == True).sum()
print(area_valid_count)
# Out:
# 16385

# %%
df.head()
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  ...  room0_valid  room1_valid  room2_valid  \
# 0                  0.000000  ...         True         True        False
# 1                  0.000000  ...         True         True        False
# 2                 12.997375  ...         True         True         True
# 3                  0.000000  ...         True        False        False
# 4                  0.000000  ...         True        False        False
#
#    room3_valid  room4_valid  room5_valid  room6_valid  room7_valid  \
# 0         True         True         True         True         True
# 1         True         True         True         True         True
# 2         True         True         True         True         True
# 3         True         True        False         True        False
# 4         True         True         True         True         True
#
#    room8_valid  room9_valid
# 0         True         True
# 1         True         True
# 2        False         True
# 3         True         True
# 4         True         True
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Image ID', 'Room 0 Area (sq. meters)', 'Room 1 Area (sq. meters)',
#        'Room 2 Area (sq. meters)', 'Room 3 Area (sq. meters)',
#        'Room 4 Area (sq. meters)', 'Room 5 Area (sq. meters)',
#        'Room 6 Area (sq. meters)', 'Room 7 Area (sq. meters)',
#        'Room 8 Area (sq. meters)', 'Room 9 Area (sq. meters)', 'Total Area',
#        'area_valid', 'room0_valid', 'room1_valid', 'room2_valid',
#        'room3_valid', 'room4_valid', 'room5_valid', 'room6_valid',
#        'room7_valid', 'room8_valid', 'room9_valid'],
#       dtype='object')

# %%
df.to_csv('filtered1.csv')

# %%
df_a=df.copy(deep=True)
for i in range(0,10):
    col_name='Room {} Area (sq. meters)'.format(i)
    new_col_name='Room {} Proportion'.format(i)
    # print(col_name)
    # print(new_col_name)
    df_a[new_col_name]=df_a[col_name]/df['Total Area']

# %%
df_a.head()
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  ...  Room 0 Proportion  Room 1 Proportion  \
# 0                  0.000000  ...           0.489663           0.191106
# 1                  0.000000  ...           0.467451           0.184947
# 2                 12.997375  ...           0.396765           0.153462
# 3                  0.000000  ...           0.433704           0.167251
# 4                  0.000000  ...           0.452223           0.178956
#
#    Room 2 Proportion  Room 3 Proportion  Room 4 Proportion  Room 5 Proportion  \
# 0           0.055889           0.060577                0.0           0.000000
# 1           0.045256           0.019708                0.0           0.100633
# 2           0.086985           0.052344                0.0           0.000000
# 3           0.054260           0.036819                0.0           0.114183
# 4           0.076429           0.052196                0.0           0.000000
#
#    Room 6 Proportion  Room 7 Proportion  Room 8 Proportion  Room 9 Proportion
# 0                0.0           0.127404           0.000000           0.075361
# 1                0.0           0.157749           0.000000           0.024255
# 2                0.0           0.126728           0.134126           0.049589
# 3                0.0           0.121339           0.000000           0.072445
# 4                0.0           0.182684           0.000000           0.057512
#
# [5 rows x 33 columns]

# %%
df_a.columns
# Out:
# Index(['Image ID', 'Room 0 Area (sq. meters)', 'Room 1 Area (sq. meters)',
#        'Room 2 Area (sq. meters)', 'Room 3 Area (sq. meters)',
#        'Room 4 Area (sq. meters)', 'Room 5 Area (sq. meters)',
#        'Room 6 Area (sq. meters)', 'Room 7 Area (sq. meters)',
#        'Room 8 Area (sq. meters)', 'Room 9 Area (sq. meters)', 'Total Area',
#        'area_valid', 'room0_valid', 'room1_valid', 'room2_valid',
#        'room3_valid', 'room4_valid', 'room5_valid', 'room6_valid',
#        'room7_valid', 'room8_valid', 'room9_valid', 'Room 0 Proportion',
#        'Room 1 Proportion', 'Room 2 Proportion', 'Room 3 Proportion',
#        'Room 4 Proportion', 'Room 5 Proportion', 'Room 6 Proportion',
#        'Room 7 Proportion', 'Room 8 Proportion', 'Room 9 Proportion'],
#       dtype='object')

# %%
prop_room_list=['Room 0 Proportion',
       'Room 1 Proportion', 'Room 2 Proportion', 'Room 3 Proportion',
       'Room 4 Proportion', 'Room 5 Proportion', 'Room 6 Proportion',
       'Room 7 Proportion', 'Room 8 Proportion', 'Room 9 Proportion']

# %%
import matplotlib.pyplot as plt

# Define the list of column names you want to create histograms for
column_list = prop_room_list

# Create a subplot grid based on the number of columns
num_columns = len(column_list)
num_rows = (num_columns + 1) // 2  # Adjust the number of rows as needed
fig, axes = plt.subplots(num_rows, 2, figsize=(12, 6 * num_rows))
axes = axes.ravel()

# Iterate through the columns and create histograms
for i, column_name in enumerate(column_list):
    ax = axes[i]
    ax.hist(df_a[column_name], bins=20)  # Adjust the number of bins as needed
    ax.set_title(column_name)
    ax.set_xlabel('Values')
    ax.set_ylabel('Frequency')

# Remove any extra empty subplots (if needed)
for j in range(num_columns, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout and display the histograms
plt.savefig("proportions_kpidea.jpg")

plt.tight_layout()
plt.show()
