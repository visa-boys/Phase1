# %%
# !pip install numpy

# %%
# !pip install scipy

# %%
# !pip install pandas

# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_data_path=r'Updated Filtered Layouts.csv'

# %%
data = pd.read_csv(original_data_path)
data.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0_x  Image ID  Room 0 Area (sq. meters)  \
# 0            2             2         2                 38.448303
# 1            4             4         4                 32.382202
# 2            9             9         9                 34.621765
# 3           16            16        16                 27.280151
# 4           22            22        22                 33.810974
# 5           48            48        48                 39.002014
# 6           53            53        53                 51.959839
# 7           62            62        62                 19.770447
# 8           66            66        66                 26.424866
# 9           77            77        77                 40.727417
# 10          88            88        88                 36.633911
# 11         107           107       107                 30.127808
# 12         124           124       124                 34.943115
# 13         127           127       127                 41.380005
# 14         139           139       139                 36.050537
# 15         144           144       144                 32.767822
# 16         147           147       147                 35.150757
# 17         153           153       153                 31.813660
# 18         155           155       155                 24.590698
# 19         163           163       163                 28.807800
#
#     Room 1 Area (sq. meters)  Room 2 Area (sq. meters)  \
# 0                  14.871094                  8.429260
# 1                  12.814453                  5.472839
# 2                  15.123230                  7.203186
# 3                  17.575378                  6.451721
# 4                  13.417603                  9.769043
# 5                  15.464355                  5.591492
# 6                  19.300781                  7.475098
# 7                   0.000000                  5.304749
# 8                  13.842773                  5.517334
# 9                  20.902588                  6.674194
# 10                 13.125916                  6.525879
# 11                 12.013550                  5.413513
# 12                 14.119629                  5.670593
# 13                 14.777161                  8.453979
# 14                 19.488647                  0.000000
# 15                 13.941650                  5.339355
# 16                 13.704346                  8.646790
# 17                 13.051758                  8.582520
# 18                 12.532654                  6.970825
# 19                 15.484131                  6.941162
#
#     Room 3 Area (sq. meters)  Room 4 Area (sq. meters)  \
# 0                   5.072388                       0.0
# 1                   3.737549                       0.0
# 2                   3.342041                       0.0
# 3                   5.210815                       0.0
# 4                   6.011719                       0.0
# 5                   3.322266                       0.0
# 6                   8.646790                       0.0
# 7                   5.487671                       0.0
# 8                   6.387451                       0.0
# 9                   4.894409                       0.0
# 10                  5.270142                       0.0
# 11                  4.152832                       0.0
# 12                  4.207214                       0.0
# 13                  6.738464                       0.0
# 14                  8.552856                       0.0
# 15                  4.671936                       0.0
# 16                  4.152832                       0.0
# 17                  9.689941                       0.0
# 18                  3.322266                       0.0
# 19                  7.910156                       0.0
#
#     Room 5 Area (sq. meters)  Room 6 Area (sq. meters)  ...  room1_valid_y  \
# 0                   0.000000                  0.000000  ...           True
# 1                   0.000000                  0.000000  ...           True
# 2                   0.000000                  0.000000  ...           True
# 3                   0.000000                  0.000000  ...           True
# 4                   0.000000                  0.000000  ...           True
# 5                   0.000000                  0.000000  ...           True
# 6                   0.000000                  0.000000  ...           True
# 7                   0.000000                  0.000000  ...           True
# 8                   0.000000                  0.000000  ...           True
# 9                   0.000000                  0.000000  ...           True
# 10                  0.000000                  0.000000  ...           True
# 11                  0.000000                  0.000000  ...           True
# 12                 11.598267                  0.000000  ...           True
# 13                  0.000000                  0.000000  ...           True
# 14                  0.000000                  0.000000  ...           True
# 15                  0.000000                  0.000000  ...           True
# 16                 13.625244                 13.625244  ...           True
# 17                  0.000000                  0.000000  ...           True
# 18                  0.000000                  0.000000  ...           True
# 19                  0.000000                  0.000000  ...           True
#
#     room2_valid_y  room3_valid_y  room4_valid_y  room5_valid_y  room6_valid_y  \
# 0            True           True           True           True           True
# 1            True           True           True           True           True
# 2            True           True           True           True           True
# 3            True           True           True           True           True
# 4            True           True           True           True           True
# 5            True           True           True           True           True
# 6            True           True           True           True           True
# 7            True           True           True           True           True
# 8            True           True           True           True           True
# 9            True           True           True           True           True
# 10           True           True           True           True           True
# 11           True           True           True           True           True
# 12           True           True           True           True           True
# 13           True           True           True           True           True
# 14           True           True           True           True           True
# 15           True           True           True           True           True
# 16           True           True           True           True           True
# 17           True           True           True           True           True
# 18           True           True           True           True           True
# 19           True           True           True           True           True
#
#     room7_valid_y  room8_valid_y  room9_valid_y  width_valid
# 0            True           True           True         True
# 1            True           True           True         True
# 2            True           True           True         True
# 3            True           True           True         True
# 4            True           True           True         True
# 5            True           True           True         True
# 6            True           True           True         True
# 7            True           True           True         True
# 8            True           True           True         True
# 9            True           True           True         True
# 10           True           True           True         True
# 11           True           True           True         True
# 12           True           True           True         True
# 13           True           True           True         True
# 14           True           True           True         True
# 15           True           True           True         True
# 16           True           True           True         True
# 17           True           True           True         True
# 18           True           True           True         True
# 19           True           True           True         True
#
# [20 rows x 47 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0_x', 'Image ID', 'Room 0 Area (sq. meters)',
#        'Room 1 Area (sq. meters)', 'Room 2 Area (sq. meters)',
#        'Room 3 Area (sq. meters)', 'Room 4 Area (sq. meters)',
#        'Room 5 Area (sq. meters)', 'Room 6 Area (sq. meters)',
#        'Room 7 Area (sq. meters)', 'Room 8 Area (sq. meters)',
#        'Room 9 Area (sq. meters)', 'Total Area', 'room0_valid_x',
#        'room1_valid_x', 'room2_valid_x', 'room3_valid_x', 'room4_valid_x',
#        'room5_valid_x', 'room6_valid_x', 'room7_valid_x', 'room8_valid_x',
#        'room9_valid_x', 'area_valid', 'Unnamed: 0_y', 'Room 0 minW (meters)',
#        'Room 1 minW (meters)', 'Room 2 minW (meters)', 'Room 3 minW (meters)',
#        'Room 4 minW (meters)', 'Room 5 minW (meters)', 'Room 6 minW (meters)',
#        'Room 7 minW (meters)', 'Room 8 minW (meters)', 'Room 9 minW (meters)',
#        'room0_valid_y', 'room1_valid_y', 'room2_valid_y', 'room3_valid_y',
#        'room4_valid_y', 'room5_valid_y', 'room6_valid_y', 'room7_valid_y',
#        'room8_valid_y', 'room9_valid_y', 'width_valid'],
#       dtype='object')

# %%
data.shape
# Out:
# (13315, 47)

# %%
for i in data.columns:
    print(i,"Minimum Value: ",min(data[i]),"Maximum Value: ",max(data[i]))
# Out:
# Image ID Minimum Value:  0 Maximum Value:  80787
# Room 0 Area (sq. meters) Minimum Value:  16.13671875 Maximum Value:  61.82775879
# Room 1 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  42.58135986
# Room 2 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  29.50982666
# Room 3 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  20.01269531
# Room 4 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  35.02716064
# Room 5 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  25.90576172
# Room 6 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  39.1305542
# Room 7 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  30.76062012
# Room 8 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  24.88238525
# Room 9 Area (sq. meters) Minimum Value:  0.0 Maximum Value:  46.48699951

# %%
room0 = data['Room 0 Area (sq. meters)']
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
room0.plot.hist(bins=60)
plt.title("Room 0 distribution")
plt.show()

# %%
## Fitting the graph for room 0
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, expon, lognorm, gamma, beta, weibull_min
from scipy.optimize import curve_fit

# Sample data (replace with your actual data)
data1 = room0

# Define the distribution functions and their names
fit_functions = [norm, expon, lognorm, beta, weibull_min]
dist_names = ['Normal', 'Exponential', 'Lognormal', 'Beta', 'Weibull']

# Create subplots
fig, axes = plt.subplots(len(fit_functions), 1, figsize=(8, 12))

# Define a custom gamma distribution function
def custom_gamma(x, k, theta):
    return gamma.pdf(x, k, scale=theta)

for i, (dist_func, dist_name) in enumerate(zip(fit_functions, dist_names)):
    # Fit the distribution to the data
    if dist_func == gamma:
        params, _ = curve_fit(custom_gamma, data1, p0=(1, 1))  # Specify initial guesses for k and theta
    else:
        params = dist_func.fit(data1)
    fitted_distribution = dist_func(*params)

    # Generate x values for the fitted distribution
    x = np.linspace(min(data1), max(data1), 1000)

    # Plot the histogram of the data
    axes[i].hist(data1, bins=30, density=True, alpha=0.5, label='Data', color='blue')

    # Plot the fitted distribution curve
    if dist_func == gamma:
        axes[i].plot(x, custom_gamma(x, *params), label=dist_name, color='red')
    else:
        axes[i].plot(x, fitted_distribution.pdf(x), label=dist_name, color='red')

    axes[i].set_title(f'{dist_name} Fit')
    axes[i].legend()

    # Generate and display the equation for the distribution
    if dist_func == norm:  # Normal Distribution
        mu, sigma = params
        equation = f'f(x) = (1/({sigma} * sqrt(2*pi))) * exp(-((x - {mu})^2) / (2*{sigma}^2))'
    
    elif dist_func == expon:  # Exponential Distribution
        lambda_ = params[0]
        equation = f'f(x) = {lambda_} * exp(-{lambda_} * x)'
    
    elif dist_func == lognorm:  # Log-Normal Distribution
        mu, sigma = params[0], params[1]
        equation = f'f(x) = (1/(x * {sigma} * sqrt(2*pi))) * exp(-((ln(x) - {mu})^2) / (2*{sigma}^2))'
    
    elif dist_func == gamma:  # Gamma Distribution
        k, theta = params
        equation = f'f(x) = ({k} * x^({k-1}) * exp(-x/{theta})) / ({theta}^{k} * gamma({k}))'
    
    elif dist_func == beta:  # Beta Distribution
        alpha, beta_ = params[0], params[1]
        equation = f'f(x) = (x^({alpha-1}) * (1-x)^({beta_-1})) / (B({alpha}, {beta_}))'
    
    elif dist_func == weibull_min:  # Weibull Distribution
        k, lambda_ = params[0], params[1]
        equation = f'f(x) = ({k}/{lambda_}) * (x/{lambda_})^({k-1}) * exp(-(x/{lambda_})^{k})'
    
    print(f'{dist_name} Equation: {equation}')

plt.tight_layout()
plt.show()
# Out:
# Normal Equation: f(x) = (1/(7.036223713828846 * sqrt(2*pi))) * exp(-((x - 33.43589147277431)^2) / (2*7.036223713828846^2))
# Exponential Equation: f(x) = 16.24053955 * exp(-16.24053955 * x)
# Lognormal Equation: f(x) = (1/(x * -17.698674717087187 * sqrt(2*pi))) * exp(-((ln(x) - 0.1371726332493145)^2) / (2*-17.698674717087187^2))
# e:\Anna University BOOKS & NOTES\SEVENTH SEMESTER\FYP\Phase1\.venv\Lib\site-packages\scipy\stats\_continuous_distns.py:719: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# Beta Equation: f(x) = (x^(6.660176019934161) * (1-x)^(19.647912639603867)) / (B(7.660176019934161, 20.647912639603867))
# Weibull Equation: f(x) = (2.684493055663457/15.79770112707451) * (x/15.79770112707451)^(1.6844930556634572) * exp(-(x/15.79770112707451)^2.684493055663457)

# %%
room1=data['Room 1 Area (sq. meters)']
tot_area=data['Total Area']
qx = sns.jointplot(x=room0, y=room1, kind="reg", 
                   height=8, joint_kws={'line_kws':{'color':'red'}})
plt.show()

# %%
room1=data['Room 1 Area (sq. meters)']
tot_area=data['Total Area']
qx = sns.jointplot(x=room0, y=tot_area, kind="reg", 
                   height=8, joint_kws={'line_kws':{'color':'red'}})
plt.show()

# %%
data.describe()
# Out:
#          Unnamed: 0  Unnamed: 0_x      Image ID  Room 0 Area (sq. meters)  \
# count  13315.000000  13315.000000  13315.000000              13315.000000
# mean   40149.372212  40149.372212  40149.372212                 33.435891
# std    24289.987001  24289.987001  24289.987001                  7.036488
# min        2.000000      2.000000      2.000000                 16.240540
# 25%    18494.000000  18494.000000  18494.000000                 28.432068
# 50%    40399.000000  40399.000000  40399.000000                 33.000183
# 75%    62596.000000  62596.000000  62596.000000                 37.869873
# max    80782.000000  80782.000000  80782.000000                 61.452026
#
#        Room 1 Area (sq. meters)  Room 2 Area (sq. meters)  \
# count              13315.000000              13315.000000
# mean                  15.504279                  6.870493
# std                    3.765623                  2.576884
# min                    0.000000                  0.000000
# 25%                   13.679626                  5.883179
# 50%                   15.217163                  6.763184
# 75%                   17.189758                  7.994202
# max                   39.437073                 29.509827
#
#        Room 3 Area (sq. meters)  Room 4 Area (sq. meters)  \
# count              13315.000000              13315.000000
# mean                   4.725497                  0.094722
# std                    1.517017                  1.142587
# min                    0.000000                  0.000000
# 25%                    3.707886                  0.000000
# 50%                    4.449463                  0.000000
# 75%                    5.458008                  0.000000
# max                   17.778076                 24.620361
#
#        Room 5 Area (sq. meters)  Room 6 Area (sq. meters)  ...  \
# count              13315.000000              13315.000000  ...
# mean                   0.125562                  0.273352  ...
# std                    1.291357                  1.846630  ...
# min                    0.000000                  0.000000  ...
# 25%                    0.000000                  0.000000  ...
# 50%                    0.000000                  0.000000  ...
# 75%                    0.000000                  0.000000  ...
# max                   24.729126                 23.804626  ...
#
#        Room 0 minW (meters)  Room 1 minW (meters)  Room 2 minW (meters)  \
# count          13315.000000          13315.000000          13315.000000
# mean               5.855840              3.522004              2.148637
# std                1.268421              0.658257              0.686364
# min                3.164062              0.000000              0.000000
# 25%                4.992188              3.304688              1.968750
# 50%                5.695312              3.515625              2.179688
# 75%                6.679688              3.796875              2.460938
# max               10.968750              7.312500              5.695312
#
#        Room 3 minW (meters)  Room 4 minW (meters)  Room 5 minW (meters)  \
# count          13315.000000          13315.000000          13315.000000
# mean               1.854497              0.023863              0.032740
# std                0.325982              0.278903              0.333368
# min                0.000000              0.000000              0.000000
# 25%                1.617188              0.000000              0.000000
# 50%                1.828125              0.000000              0.000000
# 75%                2.039062              0.000000              0.000000
# max                4.078125              5.203125              4.570312
#
#        Room 6 minW (meters)  Room 7 minW (meters)  Room 8 minW (meters)  \
# count          13315.000000          13315.000000          13315.000000
# mean               0.074215              2.968629              0.006928
# std                0.495818              0.818284              0.157248
# min                0.000000              0.000000              0.000000
# 25%                0.000000              2.812500              0.000000
# 50%                0.000000              3.093750              0.000000
# 75%                0.000000              3.375000              0.000000
# max                4.570312              5.062500              4.148438
#
#        Room 9 minW (meters)
# count          13315.000000
# mean               1.067266
# std                0.562234
# min                0.000000
# 25%                0.914062
# 50%                1.195312
# 75%                1.406250
# max                5.554688
#
# [8 rows x 25 columns]

# %%
total_area = data['Total Area']
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
total_area.plot.hist(bins=20)
plt.title("Total Carpet Area Distribution")
plt.show()

# %%
rooms_list=['Room 0 Area (sq. meters)', 'Room 1 Area (sq. meters)',
       'Room 2 Area (sq. meters)', 'Room 3 Area (sq. meters)',
       'Room 4 Area (sq. meters)', 'Room 5 Area (sq. meters)',
       'Room 6 Area (sq. meters)', 'Room 7 Area (sq. meters)',
       'Room 8 Area (sq. meters)', 'Room 9 Area (sq. meters)']

# %%
fig, axes = plt.subplots(5, 2, figsize=(12, 18))
axes = axes.ravel()  # Flatten the 2D array for easy iteration

for i, room_name in enumerate(rooms_list):
    var = data[room_name]
    axes[i].hist(var, bins=20)
    axes[i].set_title("Area of " + room_name)

# Remove any extra empty subplots (if you havefewer than 10 rooms)
for j in range(len(rooms_list), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate the correlation matrix
correlation_matrix = data[].corr()



plt.figure(figsize=(8, 6))
plt.title('Correlation Heatmap')
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(data.columns)), data.columns, rotation=45)
plt.yticks(range(len(data.columns)), data.columns)
plt.show()

# %%
data.columns
# Out:
# Index(['Image ID', 'Room 0 Area (sq. meters)', 'Room 1 Area (sq. meters)',
#        'Room 2 Area (sq. meters)', 'Room 3 Area (sq. meters)',
#        'Room 4 Area (sq. meters)', 'Room 5 Area (sq. meters)',
#        'Room 6 Area (sq. meters)', 'Room 7 Area (sq. meters)',
#        'Room 8 Area (sq. meters)', 'Room 9 Area (sq. meters)', 'Total Area'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Create subplots for house size and room size distributions
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Plot the distribution of house sizes (Histogram)
axes[0].hist(data['Total Area'], bins=10, color='skyblue', edgecolor='black')
axes[0].set_title('House Size Distribution')
axes[0].set_xlabel('House Size')
axes[0].set_ylabel('Frequency')

# Plot the distribution of room sizes (Kernel Density Plot)
import seaborn as sns
sns.kdeplot(data['Total Area'], ax=axes[1], color='red', fill=True)
axes[1].set_title('Room Size Distribution')
axes[1].set_xlabel('Room Size')
axes[1].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
min_size=dict()
min_size[0]=11.5
min_size[1]=11
min_size[2]=5
min_size[3]=1.8
min_size[4]=7.5
min_size[5]=9
min_size[6]=9
min_size[7]=7.5
min_size[8]=12
min_size[9]=1.5

# tolerance=0.15

min_width=dict()
min_width[0]=3
min_width[1]=3
min_width[2]=1.8
min_width[3]=1.2
min_width[4]=2.5
min_width[5]=3
min_width[6]=3
min_width[7]=2.5
min_width[8]=3
min_width[9]=0.7

# %%
df=data.copy(deep=True)
df.head()
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  Room 9 Area (sq. meters)  Total Area
# 0                  0.000000                  6.199585   82.265625
# 1                  0.000000                  2.689453  110.880615
# 2                 12.997375                  4.805420   96.904358
# 3                  0.000000                  4.805420   66.331604
# 4                  0.000000                  4.118225   71.606689

# %%
tolerance=0.05

# %%
room0_min_size=(df['Room 0 Area (sq. meters)']/(1) > min_size[0])
df['room0_valid']=room0_min_size
true_count = (df['room0_valid'] == True).sum()
print(true_count)
# Out:
# 80788

# %%
room1_min_size=((df['Room 1 Area (sq. meters)']/(1+tolerance) > min_size[1]) | (df['Room 1 Area (sq. meters)']==0))
df['room1_valid']=room1_min_size
true_count = (df['room1_valid'] == True).sum()
print(true_count)
# Out:
# 67700

# %%
room2_min_size=((df['Room 2 Area (sq. meters)']/(1+tolerance) > min_size[2]) | (df['Room 2 Area (sq. meters)']==0))
df['room2_valid']=room2_min_size
true_count = (df['room2_valid'] == True).sum()
print(true_count)
# Out:
# 46018

# %%
room3_min_size=((df['Room 3 Area (sq. meters)']/(1+tolerance) > min_size[3]) | (df['Room 3 Area (sq. meters)']==0))
df['room3_valid']=room3_min_size
true_count = (df['room3_valid'] == True).sum()
print(true_count)
# Out:
# 79169

# %%
room4_min_size=((df['Room 4 Area (sq. meters)']/(1+tolerance) > min_size[4]) | (df['Room 4 Area (sq. meters)']==0))
df['room4_valid']=room4_min_size
true_count = (df['room4_valid'] == True).sum()
print(true_count)
# Out:
# 80189

# %%
room5_min_size=((df['Room 5 Area (sq. meters)']/(1+tolerance) > min_size[5]) | (df['Room 5 Area (sq. meters)']==0))
df['room5_valid']=room5_min_size
true_count = (df['room5_valid'] == True).sum()
print(true_count)
# Out:
# 78672

# %%
room6_min_size=((df['Room 6 Area (sq. meters)']/(1+tolerance) > min_size[6]) | (df['Room 6 Area (sq. meters)']==0))
df['room6_valid']=room6_min_size
true_count = (df['room6_valid'] == True).sum()
print(true_count)
# Out:
# 69920

# %%
room7_min_size=((df['Room 7 Area (sq. meters)']/(1+tolerance) > min_size[7]) | (df['Room 7 Area (sq. meters)']==0))
df['room7_valid']=room7_min_size
true_count = (df['room7_valid'] == True).sum()
print(true_count)
# Out:
# 71098

# %%
room8_min_size=((df['Room 8 Area (sq. meters)']/(1+tolerance) > min_size[8]) | (df['Room 8 Area (sq. meters)']==0))
df['room8_valid']=room8_min_size
true_count = (df['room8_valid'] == True).sum()
print(true_count)
# Out:
# 80050

# %%
room9_min_size=((df['Room 9 Area (sq. meters)']/(1+tolerance) > min_size[9]) | (df['Room 9 Area (sq. meters)']==0))
df['room9_valid']=room9_min_size
true_count = (df['room9_valid'] == True).sum()
print(true_count)
# Out:
# 77276

# %%
df.head()
# Out:
#    Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 0         0                 40.282471                 15.721436
# 1         1                 51.831299                 20.507080
# 2         2                 38.448303                 14.871094
# 3         3                 28.768250                 11.093994
# 4         4                 32.382202                 12.814453
#
#    Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 0                  4.597778                  4.983398
# 1                  5.018005                  2.185181
# 2                  8.429260                  5.072388
# 3                  3.599121                  2.442261
# 4                  5.472839                  3.737549
#
#    Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 0                       0.0                  0.000000
# 1                       0.0                 11.158264
# 2                       0.0                  0.000000
# 3                       0.0                  7.573975
# 4                       0.0                  0.000000
#
#    Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  \
# 0                       0.0                 10.480957
# 1                       0.0                 17.491333
# 2                       0.0                 12.280518
# 3                       0.0                  8.048584
# 4                       0.0                 13.081421
#
#    Room 8 Area (sq. meters)  ...  room0_valid  room1_valid  room2_valid  \
# 0                  0.000000  ...         True         True        False
# 1                  0.000000  ...         True         True        False
# 2                 12.997375  ...         True         True         True
# 3                  0.000000  ...         True        False        False
# 4                  0.000000  ...         True         True         True
#
#    room3_valid  room4_valid  room5_valid  room6_valid  room7_valid  \
# 0         True         True         True         True         True
# 1         True         True         True         True         True
# 2         True         True         True         True         True
# 3         True         True        False         True         True
# 4         True         True         True         True         True
#
#    room8_valid  room9_valid
# 0         True         True
# 1         True         True
# 2         True         True
# 3         True         True
# 4         True         True
#
# [5 rows x 22 columns]

# %%
df['area_valid']=df['room0_valid'] & df['room1_valid'] & df['room2_valid'] & df['room3_valid'] & df['room4_valid'] & df['room5_valid'] & df['room6_valid'] & df['room7_valid'] & df['room8_valid'] & df['room9_valid']

# %%
area_valid_count = (df['area_valid'] == True).sum()
print(area_valid_count)
# Out:
# 29930

# %%
df.columns
# Out:
# Index(['Image ID', 'Room 0 Area (sq. meters)', 'Room 1 Area (sq. meters)',
#        'Room 2 Area (sq. meters)', 'Room 3 Area (sq. meters)',
#        'Room 4 Area (sq. meters)', 'Room 5 Area (sq. meters)',
#        'Room 6 Area (sq. meters)', 'Room 7 Area (sq. meters)',
#        'Room 8 Area (sq. meters)', 'Room 9 Area (sq. meters)', 'Total Area',
#        'room0_valid', 'room1_valid', 'room2_valid', 'room3_valid',
#        'room4_valid', 'room5_valid', 'room6_valid', 'room7_valid',
#        'room8_valid', 'room9_valid', 'area_valid'],
#       dtype='object')

# %%
df.to_csv('filtered1new.csv')

# %%
df_b=pd.read_csv('filtered1new.csv')
df_a=df_b[df_b['area_valid']==True]

# %%
for i in range(0,10):
    col_name='Room {} Area (sq. meters)'.format(i)
    new_col_name='Room {} Proportion'.format(i)
    # print(col_name)
    # print(new_col_name)
    df_a[new_col_name]=df_a[col_name]/df['Total Area']
# Out:
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']
# C:\Users\aswin\AppData\Local\Temp\ipykernel_26884\2257504261.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_a[new_col_name]=df_a[col_name]/df['Total Area']

# %%
df_a.columns
# Out:
# Index(['Unnamed: 0', 'Image ID', 'Room 0 Area (sq. meters)',
#        'Room 1 Area (sq. meters)', 'Room 2 Area (sq. meters)',
#        'Room 3 Area (sq. meters)', 'Room 4 Area (sq. meters)',
#        'Room 5 Area (sq. meters)', 'Room 6 Area (sq. meters)',
#        'Room 7 Area (sq. meters)', 'Room 8 Area (sq. meters)',
#        'Room 9 Area (sq. meters)', 'Total Area', 'room0_valid', 'room1_valid',
#        'room2_valid', 'room3_valid', 'room4_valid', 'room5_valid',
#        'room6_valid', 'room7_valid', 'room8_valid', 'room9_valid',
#        'area_valid', 'Room 0 Proportion', 'Room 1 Proportion',
#        'Room 2 Proportion', 'Room 3 Proportion', 'Room 4 Proportion',
#        'Room 5 Proportion', 'Room 6 Proportion', 'Room 7 Proportion',
#        'Room 8 Proportion', 'Room 9 Proportion'],
#       dtype='object')

# %%
df_a.head(20)
# Out:
#     Unnamed: 0  Image ID  Room 0 Area (sq. meters)  Room 1 Area (sq. meters)  \
# 2            2         2                 38.448303                 14.871094
# 4            4         4                 32.382202                 12.814453
# 5            5         5                 44.568787                 13.249512
# 8            8         8                 31.373657                 14.337158
# 9            9         9                 34.621765                 15.123230
# 15          15        15                 28.402405                 15.335815
# 16          16        16                 27.280151                 17.575378
# 18          18        18                 23.493164                 12.666138
# 19          19        19                 31.581299                 12.666138
# 20          20        20                 46.333740                 12.666138
# 22          22        22                 33.810974                 13.417603
# 32          32        32                 38.621338                 13.842773
# 33          33        33                 22.672485                 15.103455
# 44          44        44                 38.705383                 17.575378
# 45          45        45                 31.452759                 15.820312
# 48          48        48                 39.002014                 15.464355
# 52          52        52                 26.291382                 13.081421
# 53          53        53                 51.959839                 19.300781
# 55          55        55                 27.102173                 13.734009
# 61          61        61                 38.992126                 13.526367
#
#     Room 2 Area (sq. meters)  Room 3 Area (sq. meters)  \
# 2                   8.429260                  5.072388
# 4                   5.472839                  3.737549
# 5                   9.175781                  3.371704
# 8                   7.840942                  6.941162
# 9                   7.203186                  3.342041
# 15                  5.912842                  2.729004
# 16                  6.451721                  5.210815
# 18                 11.148376                  6.080933
# 19                 10.144775                  4.291260
# 20                  7.119141                  5.537109
# 22                  9.769043                  6.011719
# 32                 10.441406                  4.538452
# 33                  5.438232                  3.752380
# 44                  5.655762                  5.635986
# 45                  5.329468                  4.602722
# 48                  5.591492                  3.322266
# 52                  5.571716                  6.288574
# 53                  7.475098                  8.646790
# 55                  6.298462                  4.820251
# 61                  8.231506                  5.695312
#
#     Room 4 Area (sq. meters)  Room 5 Area (sq. meters)  \
# 2                        0.0                  0.000000
# 4                        0.0                  0.000000
# 5                        0.0                 12.137146
# 8                        0.0                  0.000000
# 9                        0.0                  0.000000
# 15                       0.0                  0.000000
# 16                       0.0                  0.000000
# 18                       0.0                  0.000000
# 19                       0.0                  0.000000
# 20                       0.0                  0.000000
# 22                       0.0                  0.000000
# 32                       0.0                  0.000000
# 33                       0.0                  0.000000
# 44                       0.0                  0.000000
# 45                       0.0                  0.000000
# 48                       0.0                  0.000000
# 52                       0.0                  0.000000
# 53                       0.0                  0.000000
# 55                       0.0                  0.000000
# 61                       0.0                  0.000000
#
#     Room 6 Area (sq. meters)  Room 7 Area (sq. meters)  ...  \
# 2                   0.000000                 12.280518  ...
# 4                   0.000000                 13.081421  ...
# 5                   9.492188                  0.000000  ...
# 8                   0.000000                 11.761414  ...
# 9                   0.000000                 12.280518  ...
# 15                  0.000000                  9.096680  ...
# 16                  0.000000                 16.334473  ...
# 18                  0.000000                 14.475586  ...
# 19                  0.000000                 11.835571  ...
# 20                  0.000000                 12.666138  ...
# 22                  0.000000                 11.311523  ...
# 32                 12.399170                 10.901184  ...
# 33                  0.000000                  9.729492  ...
# 44                 12.211304                 12.399170  ...
# 45                 11.934448                 11.351074  ...
# 48                  0.000000                 10.916016  ...
# 52                  0.000000                 12.547485  ...
# 53                  0.000000                 12.967712  ...
# 55                 11.469727                  9.947021  ...
# 61                  0.000000                  8.780273  ...
#
#     Room 0 Proportion  Room 1 Proportion  Room 2 Proportion  \
# 2            0.396765           0.153462           0.086985
# 4            0.452223           0.178956           0.076429
# 5            0.484469           0.144024           0.099742
# 8            0.413070           0.188765           0.103235
# 9            0.466587           0.203811           0.097075
# 15           0.417484           0.225420           0.086912
# 16           0.374457           0.241246           0.088559
# 18           0.325680           0.175588           0.154547
# 19           0.429417           0.172224           0.137940
# 20           0.528655           0.144517           0.081227
# 22           0.454932           0.180536           0.131444
# 32           0.408898           0.146558           0.110547
# 33           0.375286           0.250000           0.090016
# 44           0.397795           0.180631           0.058127
# 45           0.390762           0.196548           0.066212
# 48           0.485417           0.192469           0.069591
# 52           0.378910           0.188529           0.080299
# 53           0.489247           0.181734           0.070385
# 55           0.327069           0.165742           0.076010
# 61           0.483895           0.167863           0.102154
#
#     Room 3 Proportion  Room 4 Proportion  Room 5 Proportion  \
# 2            0.052344                0.0           0.000000
# 4            0.052196                0.0           0.000000
# 5            0.036651                0.0           0.131933
# 8            0.091388                0.0           0.000000
# 9            0.045040                0.0           0.000000
# 15           0.040113                0.0           0.000000
# 16           0.071526                0.0           0.000000
# 18           0.084299                0.0           0.000000
# 19           0.058349                0.0           0.000000
# 20           0.063177                0.0           0.000000
# 22           0.080889                0.0           0.000000
# 32           0.048050                0.0           0.000000
# 33           0.062111                0.0           0.000000
# 44           0.057924                0.0           0.000000
# 45           0.057183                0.0           0.000000
# 48           0.041349                0.0           0.000000
# 52           0.090631                0.0           0.000000
# 53           0.081417                0.0           0.000000
# 55           0.058171                0.0           0.000000
# 61           0.070679                0.0           0.000000
#
#     Room 6 Proportion  Room 7 Proportion  Room 8 Proportion  Room 9 Proportion
# 2            0.000000           0.126728           0.134126           0.049589
# 4            0.000000           0.182684           0.000000           0.057512
# 5            0.103181           0.000000           0.000000           0.000000
# 8            0.000000           0.154853           0.000000           0.048688
# 9            0.000000           0.165501           0.000000           0.021987
# 15           0.000000           0.133711           0.000000           0.096359
# 16           0.000000           0.224213           0.000000           0.000000
# 18           0.000000           0.200672           0.000000           0.059215
# 19           0.000000           0.160930           0.000000           0.041140
# 20           0.000000           0.144517           0.000000           0.037906
# 22           0.000000           0.152198           0.000000           0.000000
# 32           0.131275           0.115415           0.000000           0.039257
# 33           0.000000           0.161047           0.000000           0.061538
# 44           0.125502           0.127433           0.000000           0.052589
# 45           0.148271           0.141023           0.000000           0.000000
# 48           0.000000           0.135860           0.000000           0.075314
# 52           0.000000           0.180834           0.000000           0.080798
# 53           0.000000           0.122102           0.000000           0.055116
# 55           0.138417           0.120041           0.000000           0.114552
# 61           0.000000           0.108964           0.000000           0.066446
#
# [20 rows x 34 columns]

# %%
prop_room_list=['Room 0 Proportion',
       'Room 1 Proportion', 'Room 2 Proportion', 'Room 3 Proportion',
       'Room 4 Proportion', 'Room 5 Proportion', 'Room 6 Proportion',
       'Room 7 Proportion', 'Room 8 Proportion', 'Room 9 Proportion']

# %%
## try to make a pie chart of proportions of each room

# %%
original_width_path=r'room_minWNEW.csv'

# %%
data2 = pd.read_csv(original_width_path)

# %%
data2.head(20)
# Out:
#     Image ID  Room 0 minW (meters)  Room 1 minW (meters)  \
# 0          0              5.203125              3.726562
# 1          1              5.343750              4.289062
# 2          2              4.921875              3.304688
# 3          3              4.851562              3.093750
# 4          4              5.203125              3.375000
# 5          5              6.328125              2.812500
# 6          6              6.187500              3.164062
# 7          7              8.507812              3.304688
# 8          8              5.835938              3.515625
# 9          9              3.726562              3.304688
# 10        10              5.414062              3.445312
# 11        11              7.875000              3.867188
# 12        12              5.484375              3.585938
# 13        13              6.468750              4.289062
# 14        14              5.765625              2.882812
# 15        15              5.695312              3.304688
# 16        16              5.203125              3.164062
# 17        17              4.570312              3.375000
# 18        18              3.796875              2.953125
# 19        19              4.781250              2.953125
#
#     Room 2 minW (meters)  Room 3 minW (meters)  Room 4 minW (meters)  \
# 0               2.109375              1.968750              0.000000
# 1               2.039062              1.195312              0.000000
# 2               2.179688              1.898438              0.000000
# 3               1.828125              1.335938              0.000000
# 4               1.898438              1.476562              0.000000
# 5               2.250000              1.546875              0.000000
# 6               1.968750              1.898438              0.000000
# 7               1.687500              1.406250              0.000000
# 8               1.828125              1.898438              0.000000
# 9               2.179688              1.828125              0.000000
# 10              1.476562              1.406250              0.000000
# 11              1.476562              1.476562              0.000000
# 12              1.968750              2.109375              0.000000
# 13              1.476562              1.546875              0.000000
# 14              1.828125              1.125000              3.796875
# 15              1.828125              1.617188              0.000000
# 16              2.039062              2.179688              0.000000
# 17              2.742188              1.898438              1.546875
# 18              2.882812              2.109375              0.000000
# 19              2.531250              1.968750              0.000000
#
#     Room 5 minW (meters)  Room 6 minW (meters)  Room 7 minW (meters)  \
# 0               0.000000              0.000000              2.812500
# 1               2.601562              0.000000              4.078125
# 2               0.000000              0.000000              3.234375
# 3               2.953125              0.000000              2.601562
# 4               0.000000              0.000000              3.445312
# 5               2.812500              2.812500              0.000000
# 6               0.000000              2.039062              2.953125
# 7               0.000000              0.000000              2.460938
# 8               0.000000              0.000000              2.742188
# 9               0.000000              0.000000              3.234375
# 10              0.000000              0.000000              3.445312
# 11              0.000000              0.000000              2.812500
# 12              0.000000              0.000000              2.742188
# 13              0.000000              1.687500              3.023438
# 14              0.000000              2.953125              2.812500
# 15              0.000000              0.000000              2.812500
# 16              0.000000              0.000000              3.937500
# 17              0.000000              0.000000              3.445312
# 18              0.000000              0.000000              3.375000
# 19              0.000000              0.000000              2.953125
#
#     Room 8 minW (meters)  Room 9 minW (meters)
# 0               0.000000              1.546875
# 1               0.000000              0.562500
# 2               3.304688              1.265625
# 3               0.000000              1.265625
# 4               0.000000              1.195312
# 5               0.000000              0.000000
# 6               0.000000              0.632812
# 7               0.000000              1.054688
# 8               0.000000              1.195312
# 9               0.000000              0.773438
# 10              0.000000              0.000000
# 11              0.000000              0.351562
# 12              0.000000              1.125000
# 13              1.617188              0.843750
# 14              0.000000              0.000000
# 15              0.000000              1.828125
# 16              0.000000              0.000000
# 17              0.000000              1.546875
# 18              0.000000              1.265625
# 19              0.000000              1.195312

# %%
data2.columns
# Out:
# Index(['Image ID', 'Room 0 minW (meters)', 'Room 1 minW (meters)',
#        'Room 2 minW (meters)', 'Room 3 minW (meters)', 'Room 4 minW (meters)',
#        'Room 5 minW (meters)', 'Room 6 minW (meters)', 'Room 7 minW (meters)',
#        'Room 8 minW (meters)', 'Room 9 minW (meters)'],
#       dtype='object')

# %%
data2.shape
# Out:
# (80788, 11)

# %%
data2.describe()
# Out:
#            Image ID  Room 0 minW (meters)  Room 1 minW (meters)  \
# count  80788.000000          80788.000000          80788.000000
# mean   40393.500000              5.885418              3.277885
# std    23321.631111              1.253749              0.578463
# min        0.000000              1.898438              0.000000
# 25%    20196.750000              4.992188              3.093750
# 50%    40393.500000              5.695312              3.234375
# 75%    60590.250000              6.750000              3.515625
# max    80787.000000             11.460938              7.312500
#
#        Room 2 minW (meters)  Room 3 minW (meters)  Room 4 minW (meters)  \
# count          80788.000000          80788.000000          80788.000000
# mean               1.832604              1.683918              0.041178
# std                0.555913              0.321328              0.331983
# min                0.000000              0.000000              0.000000
# 25%                1.617188              1.476562              0.000000
# 50%                1.828125              1.687500              0.000000
# 75%                2.109375              1.898438              0.000000
# max                5.695312              4.851562              8.296875
#
#        Room 5 minW (meters)  Room 6 minW (meters)  Room 7 minW (meters)  \
# count          80788.000000          80788.000000          80788.000000
# mean               0.129464              0.466709              2.745984
# std                0.583851              0.995068              0.731058
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              2.601562
# 50%                0.000000              0.000000              2.812500
# 75%                0.000000              0.000000              3.093750
# max                5.554688              5.835938              6.117188
#
#        Room 8 minW (meters)  Room 9 minW (meters)
# count          80788.000000          80788.000000
# mean               0.028011              1.020483
# std                0.278582              0.575211
# min                0.000000              0.000000
# 25%                0.000000              0.843750
# 50%                0.000000              1.125000
# 75%                0.000000              1.335938
# max                4.148438             11.601562

# %%
rooms_list2=['Room 0 minW (meters)','Room 1 minW (meters)',
       'Room 2 minW (meters)', 'Room 3 minW (meters)', 'Room 4 minW (meters)',
       'Room 5 minW (meters)', 'Room 6 minW (meters)', 'Room 7 minW (meters)',
       'Room 8 minW (meters)', 'Room 9 minW (meters)']

# %%
# fig, axes = plt.subplots(5, 2, figwidth=(12, 18))
# axes = axes.ravel()  # Flatten the 2D array for easy iteration

# for i, room_name in enumerate(rooms_list2):
#     var = data[room_name]
#     axes[i].hist(var, bins=20)
#     axes[i].set_title("Area of " + room_name)

# # Remove any extra empty subplots (if you have fewer than 10 rooms)
# for j in range(len(rooms_list2), len(axes)):
#     fig.delaxes(axes[j])

# plt.tight_layout()
# plt.show()

# %%
min_width=dict()
min_width[0]=3
min_width[1]=3
min_width[2]=1.8
min_width[3]=1.2
min_width[4]=2.5
min_width[5]=3
min_width[6]=3
min_width[7]=2.5
min_width[8]=3
min_width[9]=0.7

# %%
df2=data2.copy(deep=True)
df2.head()
# Out:
#    Image ID  Room 0 minW (meters)  Room 1 minW (meters)  Room 2 minW (meters)  \
# 0         0              5.203125              3.726562              2.109375
# 1         1              5.343750              4.289062              2.039062
# 2         2              4.921875              3.304688              2.179688
# 3         3              4.851562              3.093750              1.828125
# 4         4              5.203125              3.375000              1.898438
#
#    Room 3 minW (meters)  Room 4 minW (meters)  Room 5 minW (meters)  \
# 0              1.968750                   0.0              0.000000
# 1              1.195312                   0.0              2.601562
# 2              1.898438                   0.0              0.000000
# 3              1.335938                   0.0              2.953125
# 4              1.476562                   0.0              0.000000
#
#    Room 6 minW (meters)  Room 7 minW (meters)  Room 8 minW (meters)  \
# 0                   0.0              2.812500              0.000000
# 1                   0.0              4.078125              0.000000
# 2                   0.0              3.234375              3.304688
# 3                   0.0              2.601562              0.000000
# 4                   0.0              3.445312              0.000000
#
#    Room 9 minW (meters)
# 0              1.546875
# 1              0.562500
# 2              1.265625
# 3              1.265625
# 4              1.195312

# %%
tolerance=0.05

# %%
# width_condition = (df2['Room 0 minW (meters)']/(1+tolerance) > min_width[0]) & (df2['Room 1 minW (meters)']/(1+tolerance) > min_width[1]) & (df2['Room 2 minW (meters)']/(1+tolerance) > min_width[2]) & (df2['Room 3 minW (meters)']/(1+tolerance) > min_width[3]) & (df2['Room 4 minW (meters)']/(1+tolerance) > min_width[4]) & (df2['Room 5 minW (meters)']/(1+tolerance) > min_width[5]) & (df2['Room 6 minW (meters)']/(1+tolerance) > min_width[6]) & (df2['Room 7 minW (meters)']/(1+tolerance) > min_width[7]) & (df2['Room 8 minW (meters)']/(1+tolerance) > min_width[8]) & (df2['Room 9 minW (meters)']/(1+tolerance) > min_width[9])

# %%
# df2['width_valid'] = width_condition

# %%
df2.head()
# Out:
#    Image ID  Room 0 minW (meters)  Room 1 minW (meters)  Room 2 minW (meters)  \
# 0         0              5.203125              3.726562              2.109375
# 1         1              5.343750              4.289062              2.039062
# 2         2              4.921875              3.304688              2.179688
# 3         3              4.851562              3.093750              1.828125
# 4         4              5.203125              3.375000              1.898438
#
#    Room 3 minW (meters)  Room 4 minW (meters)  Room 5 minW (meters)  \
# 0              1.968750                   0.0              0.000000
# 1              1.195312                   0.0              2.601562
# 2              1.898438                   0.0              0.000000
# 3              1.335938                   0.0              2.953125
# 4              1.476562                   0.0              0.000000
#
#    Room 6 minW (meters)  Room 7 minW (meters)  Room 8 minW (meters)  \
# 0                   0.0              2.812500              0.000000
# 1                   0.0              4.078125              0.000000
# 2                   0.0              3.234375              3.304688
# 3                   0.0              2.601562              0.000000
# 4                   0.0              3.445312              0.000000
#
#    Room 9 minW (meters)
# 0              1.546875
# 1              0.562500
# 2              1.265625
# 3              1.265625
# 4              1.195312

# %%
room0_min_size=((df2['Room 0 minW (meters)']/(1+tolerance) > min_width[0]) | (df2['Room 0 minW (meters)']==0))
df2['room0_valid']=room0_min_size
true_count = (df2['room0_valid'] == True).sum()
print(true_count)
# Out:
# 80509

# %%
room1_min_size=((df2['Room 1 minW (meters)']/(1+tolerance) > min_width[1]) | (df2['Room 1 minW (meters)']==0))
df2['room1_valid']=room1_min_size
true_count = (df2['room1_valid'] == True).sum()
print(true_count)
# Out:
# 56070

# %%
room2_min_size=((df2['Room 2 minW (meters)']/(1+tolerance) > min_width[2]) | (df2['Room 2 minW (meters)']==0))
df2['room2_valid']=room2_min_size
true_count = (df2['room2_valid'] == True).sum()
print(true_count)
# Out:
# 40124

# %%
room3_min_size=((df2['Room 3 minW (meters)']/(1+tolerance) > min_width[3]) | (df2['Room 3 minW (meters)']==0))
df2['room3_valid']=room3_min_size
true_count = (df2['room3_valid'] == True).sum()
print(true_count)
# Out:
# 76387

# %%
room4_min_size=((df2['Room 4 minW (meters)']/(1+tolerance) > min_width[4]) | (df2['Room 4 minW (meters)']==0))
df2['room4_valid']=room4_min_size
true_count = (df2['room4_valid'] == True).sum()
print(true_count)
# Out:
# 79991

# %%
room5_min_size=((df2['Room 5 minW (meters)']/(1+tolerance) > min_width[5]) | (df2['Room 5 minW (meters)']==0))
df2['room5_valid']=room5_min_size
true_count = (df2['room5_valid'] == True).sum()
print(true_count)
# Out:
# 77428

# %%
room6_min_size=((df2['Room 6 minW (meters)']/(1+tolerance) > min_width[6]) | (df2['Room 6 minW (meters)']==0))
df2['room6_valid']=room6_min_size
true_count = (df2['room6_valid'] == True).sum()
print(true_count)
# Out:
# 66714

# %%
room7_min_size=((df2['Room 7 minW (meters)']/(1+tolerance) > min_width[7]) | (df2['Room 7 minW (meters)']==0))
df2['room7_valid']=room7_min_size
true_count = (df2['room7_valid'] == True).sum()
print(true_count)
# Out:
# 61264

# %%
room8_min_size=((df2['Room 8 minW (meters)']/(1+tolerance) > min_width[8]) | (df2['Room 8 minW (meters)']==0))
df2['room8_valid']=room8_min_size
true_count = (df2['room8_valid'] == True).sum()
print(true_count)
# Out:
# 80087

# %%
room9_min_size=((df2['Room 9 minW (meters)']/(1+tolerance) > min_width[9]) | (df2['Room 9 minW (meters)']==0))
df2['room9_valid']=room9_min_size
true_count = (df2['room9_valid'] == True).sum()
print(true_count)
# Out:
# 76710

# %%
df2.head()
# Out:
#    Image ID  Room 0 minW (meters)  Room 1 minW (meters)  Room 2 minW (meters)  \
# 0         0              5.203125              3.726562              2.109375
# 1         1              5.343750              4.289062              2.039062
# 2         2              4.921875              3.304688              2.179688
# 3         3              4.851562              3.093750              1.828125
# 4         4              5.203125              3.375000              1.898438
#
#    Room 3 minW (meters)  Room 4 minW (meters)  Room 5 minW (meters)  \
# 0              1.968750                   0.0              0.000000
# 1              1.195312                   0.0              2.601562
# 2              1.898438                   0.0              0.000000
# 3              1.335938                   0.0              2.953125
# 4              1.476562                   0.0              0.000000
#
#    Room 6 minW (meters)  Room 7 minW (meters)  Room 8 minW (meters)  ...  \
# 0                   0.0              2.812500              0.000000  ...
# 1                   0.0              4.078125              0.000000  ...
# 2                   0.0              3.234375              3.304688  ...
# 3                   0.0              2.601562              0.000000  ...
# 4                   0.0              3.445312              0.000000  ...
#
#    room0_valid  room1_valid  room2_valid  room3_valid  room4_valid  \
# 0         True         True         True         True         True
# 1         True         True         True        False         True
# 2         True         True         True         True         True
# 3         True        False        False         True         True
# 4         True         True         True         True         True
#
#    room5_valid  room6_valid  room7_valid  room8_valid  room9_valid
# 0         True         True         True         True         True
# 1        False         True         True         True        False
# 2         True         True         True         True         True
# 3        False         True        False         True         True
# 4         True         True         True         True         True
#
# [5 rows x 21 columns]

# %%
df2['width_valid']=df2['room0_valid'] & df2['room1_valid'] & df2['room2_valid'] & df2['room3_valid'] & df2['room4_valid'] & df2['room5_valid'] & df2['room6_valid'] & df2['room7_valid'] & df2['room8_valid'] & df2['room9_valid']

# %%
width_valid_count = (df2['width_valid'] == True).sum()
print(width_valid_count)
# Out:
# 16918

# %%
df2.to_csv('filtered2new.csv')
